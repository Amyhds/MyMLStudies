# %%
# Lab 4 Multi-variable linear regression
import tensorflow as tf
import numpy as np
tf.set_random_seed(777)  # for reproducibility

xy = np.loadtxt('happiness.csv', delimiter=',', dtype=np.float32)
np.arr1 = xy[:,1:3]
np.arr2 = xy[:,4:-2]

x_data =np.hstack([np.arr1,np.arr2])
y_data = xy[:, [3]]

# Make sure the shape and data are OK
print(x_data, "\nx_data shape:", x_data.shape)
print(y_data, "\ny_data shape:", y_data.shape)
# Out:
# [[1.39651 1.34951 0.66557 0.41978 0.29678]
#  [1.30232 1.40223 0.62877 0.14145 0.4363 ]
#  [1.32548 1.36058 0.64938 0.48357 0.34139]
#  [1.459   1.33095 0.66973 0.36503 0.34699]
#  [1.32629 1.32261 0.63297 0.32957 0.45811]
#  [1.29025 1.31826 0.64169 0.41372 0.23351]
#  [1.32944 1.28017 0.61576 0.31814 0.4761 ]
#  [1.33171 1.28907 0.6598  0.43844 0.36262]
#  [1.25018 1.31967 0.63938 0.42922 0.47501]
#  [1.33358 1.30923 0.65124 0.35637 0.43562]
#  [1.22857 1.22393 0.41319 0.07785 0.33172]
#  [0.95578 1.23788 0.63376 0.10583 0.25497]
#  [1.33723 1.29704 0.62433 0.18676 0.33088]
#  [1.02054 0.91451 0.48181 0.21312 0.14074]
#  [1.39451 1.24711 0.54604 0.1589  0.40105]
#  [0.98124 1.23287 0.49049 0.17521 0.14574]
#  [1.56391 1.21963 0.61583 0.37798 0.28034]
#  [1.33596 1.36948 0.61777 0.28703 0.45901]
#  [1.30782 1.28566 0.5845  0.2254  0.2225 ]
#  [1.42727 1.12575 0.64157 0.38583 0.26428]
#  [1.26637 1.28548 0.59625 0.32067 0.51912]
#  [1.36011 1.08182 0.63274 0.32524 0.21542]
# ...

# %%
# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 5])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([5, 1]), name='pred1')
b = tf.Variable(tf.random_normal([1]), name='pred2')

# Hypothesis
hypothesis = tf.matmul(X, W) + b

# Simplified cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train], 
                                   feed_dict={X: x_data, Y: y_data})
    if step % 100 == 0:
        print(step, "Cost:", cost_val, "\nPrediction:\n", hy_val)
# Out:
# WARNING:tensorflow:From C:\Users\dasom\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 0 Cost: 0.395095
# Prediction:
#  [[ 1.4669688 ]
#  [ 1.5145688 ]
#  [ 1.4041802 ]
#  [ 1.5009538 ]
#  [ 1.4106444 ]
#  [ 1.4105699 ]
#  [ 1.4033554 ]
#  [ 1.3553045 ]
#  [ 1.304219  ]
#  [ 1.3838171 ]
#  [ 1.6479139 ]
#  [ 1.18465   ]
#  [ 1.4947498 ]
#  [ 1.2040497 ]
#  [ 1.5893719 ]
#  [ 1.3880339 ]
#  [ 1.5914901 ]
#  [ 1.4814246 ]
#  [ 1.5329746 ]
#  [ 1.3892429 ]
#  [ 1.3662657 ]
#  [ 1.3495761 ]
#  [ 1.5751952 ]
#  [ 1.4673672 ]
#  [ 1.3632226 ]
#  [ 1.5056089 ]
#  [ 1.4326195 ]
#  [ 1.5096884 ]
#  [ 1.5694212 ]
#  [ 1.5431198 ]
#  [ 1.6186649 ]
#  [ 1.2508582 ]
#  [ 1.3151944 ]
#  [ 1.2310232 ]
#  [ 1.7953842 ]
#  [ 1.7032932 ]
#  [ 1.3780372 ]
#  [ 1.6395476 ]
# ...

# %%
# Ask my score
print("1st life expectancy will be ", sess.run(hypothesis, 
                                      feed_dict={X: [[1.23, 1.22, 0.41, 0.08, 0.33]]}))

print("2nd life expectancy will be ", sess.run(hypothesis, 
                                      feed_dict={X: [[0.96, 1.24, 0.63, 0.11, 0.25]]}))
# Out:
# 1st life expectancy will be  [[0.8839816]]
# 2nd life expectancy will be  [[0.6188247]]
